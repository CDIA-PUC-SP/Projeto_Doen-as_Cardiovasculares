# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
figura = plt.figure(figsize=(15,10))
plt.rcParams['font.size'] = '15'
plt.bar(['Doenças Cardiovasculares'],[397993])
plt.bar(['Neoplasia'],[266014])
plt.bar(['Diabetes e Falência Renal'],[107760])
plt.bar(['Infecções Respiratórias'],[94264])
plt.bar(['Violência'],[80502])
plt.legend(['Doenças Cardiovasculares: 28,81%','Neoplasia: 18,85%','Diabetes e Falência Renal: 7.64%','Infecções Respiratórias: 6,68%','Violência: 5,71%'], loc='upper right', shadow=True)
plt.title("Principais causas de morte no Brasil (2019)", fontsize = "25", style='italic')
plt.ylabel("Número de mortes", fontsize="20", style='italic')
plt.gcf().autofmt_xdate()
plt.show(figura)

# %%
figura = plt.figure(figsize=(15,10))
plt.rcParams['font.size'] = '15'
plt.bar(['Doenças isquêmicas do coração'],[117549])
plt.bar(['Doenças cerebrovasculares'],[101074])
plt.bar(['Infarto agudo do miocárdio'],[95557])
plt.bar(['Outras doenças cardíacas'],[70761])
plt.bar(['Doenças hipertensivas'],[53796])
plt.bar(['Doenças Aterosclerose'],[1011])
plt.bar(['Rest doenças do aparelho'],[17821])


plt.legend(['Doenças isquêmicas do coração: 25,69%', 'Doenças cerebrovasculares: 22,09%', 'Infarto agudo do miocárdio: 20,88%', 'Outras doenças cardíacas: 15,46%', 'Doenças hipertensivas:11,76%', 'Aterosclerose: 0,2%', 'Rest doenças do aparelho circulatorio: 3,89%'], loc='upper right', shadow=True)
plt.title("Doenças Cardiovasculares (2019)", fontsize = "25", style='italic')
plt.ylabel("Número de mortes", fontsize="20", style='italic')
plt.gcf().autofmt_xdate()
plt.show(figura)

# %%
figura = plt.figure(figsize=(15,10))
plt.rcParams['font.size'] = '15'
plt.bar(['Jovens'],[1476])
plt.bar(['Adultos (Grupo 1)'],[9203])
plt.bar(['Adultos (Grupo 2)'],[59738])
plt.bar(['Idosos'],[293243])
plt.legend(['Jovens: Até 19 anos','Adultos: Até 40 anos','Adultos: Até 60 anos','Idosos: A partir de 60 anos'], loc='upper left', shadow=True)
plt.title("Mortes por faixa etária (2019)", fontsize = "25", style='italic')
plt.ylabel("Número de mortes", fontsize="20", style='italic')
plt.gcf().autofmt_xdate()
plt.show(figura)

# %%
figura1 = plt.figure(figsize=(15,10))
plt.rcParams['font.size'] = '15'
plt.bar(['Brancos'],[238080])
plt.bar(['Pardos'],[168192])
plt.bar(['Pretos'],[39334])
plt.bar(['Amarelo'],[10673])
plt.bar(['Indigenas'],[897])
plt.bar(['Não declarados'],[2513])

plt.legend(['Brancos: 51,79%', 'Pardo: 36,59%', 'Pretos: 8,56%','Amarelo: 0,54%','Indigenas: 0,1%','Não declarados: 2,96%'], loc='upper right', shadow=True)
plt.title("Mortes Cardiovasculares por Cor/Raça (2019)", fontsize = "25", style='italic')
plt.ylabel("Número de mortes", fontsize="20", style='italic')
plt.gcf().autofmt_xdate()

figura2 = plt.figure(figsize=(10,5))

# Fonte desses dao=dos abaixo é IPEA - Atlas da violencia.

plt.rcParams['font.size'] = '10'
plt.bar(['Pretos'],[34466])
plt.bar(['Não Pretos'],[10217])

plt.legend(['Pretos: 77,2%', 'Não Pretos: 22,8%'], loc='upper right', shadow=True)
plt.title("Mortes por violência relacionadas com Cor/Raça (2019)", fontsize = "25", style='italic')
plt.ylabel("Número de mortes", fontsize="20", style='italic')
plt.gcf().autofmt_xdate()
plt.show(figura1, figura2)

# %%
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw=dict(aspect="equal"))

recipe = ["Homem: 53%", "Mulher: 47%"]

data = [191722, 172385]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Mortes por gênero")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw=dict(aspect="equal"))

recipe = ["Pretos e Pardos: 78%", "Outros: 22%"]

data = [34466, 10217]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=0)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Mortes de violência por cor")

plt.show()

# %%
# plotagem de gráficos a partir dos dados
plt.rcParams['font.size'] = '15'
plt.figure(figsize=(15,7))
x = ["2016", "2017", "2018", "2019", "2020"]
y = [362091, 358882, 357770, 364132, 357741]
plt.text("2016", 362091, "362K")
plt.text("2017", 358882, "358K")
plt.text("2018", 357770, "357K")
plt.text("2019", 364132, "364K")
plt.text("2020", 357741, "357K")
plt.plot(x, y, label="Total de Alunos", color="r", marker="o")
plt.title("Evolução da Quantidade de Casos", fontsize = "25", style='italic')
plt.ylabel("Quantidade de Casos", fontsize="15", style='italic')
plt.grid(True)
plt.legend()
plt.show()
